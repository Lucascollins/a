# %%
! pip install pandas
! pip install tk
! pip install selenium
! pip install pyautogui
# Out:
# Requirement already satisfied: pandas in c:\users\start\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\start\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\start\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Collecting tk
#   Downloading tk-0.1.0-py3-none-any.whl (3.9 kB)
# Installing collected packages: tk
# Successfully installed tk-0.1.0
# Collecting selenium
#   Downloading selenium-4.1.0-py3-none-any.whl (958 kB)
# Requirement already satisfied: urllib3[secure]~=1.26 in c:\users\start\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Collecting trio~=0.17
#   Downloading trio-0.19.0-py3-none-any.whl (356 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sniffio in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Collecting outcome
#   Downloading outcome-1.1.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sortedcontainers in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: cffi>=1.14 in c:\users\start\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\start\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\start\anaconda3\lib\site-packages (from urllib3[secure]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\start\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.13.0 outcome-1.1.0 selenium-4.1.0 trio-0.19.0 trio-websocket-0.9.2 wsproto-1.0.0
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.4.tar.gz (14 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36613 sha256=a5f702d5c38190cf6d91d7871c7b77e4d263aa132c48825948e83aa5fe19d8d3
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\d8\97\e4\d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11080 sha256=fa36170a8f5afcd0da3233d9196a1583d812165206685e7dc59ebc56a1d6fa27
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\44\ab\20\423c3a444793767e4e41f8377bc902f77bee212e68dcce85a5
#   Building wheel for pyscreeze (PEP 517): started
#   Building wheel for pyscreeze (PEP 517): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13021 sha256=18d3762caafe027f0ccd220595740af6dd955774d3ebcf831857715acab0cc73
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\a2\5b\86\99f1d8fac5d92de0ccb3f0d4ad15e3f4278baf75a9b0f20b93
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=pytweening-1.0.4-py3-none-any.whl size=5854 sha256=02b713e7feb936c2f6d4ddf2d7e78906ca9da954fa8cff8edce931a5eee93490
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\a4\5d\d2\ba4c8f82163233ffaadcf383c1e34d7d92635d357d13e7b78d
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=3fd44c0da1156a7381f664d54457f0c2aacd98c4d225994af3cf77c14f809de6
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\61\73\b9\6fb1131ab36e650206e3aa0ad7a68907b41b32ac2d4f75f543
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=f4e836b2d83aad183e96072ef1c74915535c705adb2118194c756c1bcf7c3cb5
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\7f\13\8c\584c519464297d9637f9cd29fd1dcdf55e2a2cab225c76a2db
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11136 sha256=e9c06680d07864b223f7543528737bece373ad35e2de9ade4d758605231d9748
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\0c\09\9e\49e21a6840ef7955b06d47394afef0058f0378c0914e48b8b8
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9547 sha256=8a034e18aed8ebfec64775902fa0e075ee8999160e37023fb2123c311b73e327
#   Stored in directory: c:\users\start\appdata\local\pip\cache\wheels\0e\d4\c5\b7f7be24ac0a168fd03d08afcc7c8928ef05cc1e319d1c136b
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.4 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.28

# %%
#Importando bibliotecas
from selenium import webdriver
import tkinter as tk
import pandas as pd
import pyautogui
import time


#Layout
root = tk.Tk()
root.title("Bot mandar Mensagem")

_nameSheet= Label(root,text ="Nome Planilha")
_nameSheet.grid(column = 0,row = 0)
_inputSheet = Entry(root,width = 150)
_inputSheet.grid(column = 1,row = 0)

text_mensagem = Label(root,text ="Mensagem")
text_mensagem.grid(column = 0,row = 1)
text = Entry(root,width =150)
text.grid(column = 1,row = 1)

#Logica do programa




            
def excel():
    n = 0
    _sheet = _inputSheet.get()
    _text = text.get()
    df =pd.read_excel(f"C:/Users/start/Downloads/{_sheet}.xlsx")
    alunos = df["Aluno(a)"]
    telefones = df["Telefone(s)"]
    num = len(telefones)
    
    nav = webdriver.Chrome()
    nav.get('https://web.whatsapp.com/')

    while len(nav.find_elements_by_id('side')) < 1:
        time.sleep(1)

    while n <= len(telefones): 
        link =f"https://web.whatsapp.com/send?phone={telefones[n]}&text={_text}"
        nav.get(link)
        n+= 1




button = Button(root,bg="blue",text="Mandar",command=excel)
button.grid(column = 0 ,row=5)

root.mainloop()
# Out:
# C:\Users\start\AppData\Local\Temp/ipykernel_2608/2454586186.py:41: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   while len(nav.find_elements_by_id('side')) < 1:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\indexes\range.py", line 385, in get_loc
#     return self._range.index(new_key)
# ValueError: 1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\start\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\start\AppData\Local\Temp/ipykernel_2608/2454586186.py", line 45, in excel
#     link =f"https://web.whatssapp.com/send?phone={telefones[n]}&text={_text}"
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\series.py", line 942, in __getitem__
#     return self._get_value(key)
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\series.py", line 1051, in _get_value
#     loc = self.index.get_loc(label)
#   File "C:\Users\start\anaconda3\lib\site-packages\pandas\core\indexes\range.py", line 387, in get_loc
#     raise KeyError(key) from err
# KeyError: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2608/2454586186.py in <module>
#      53 button.grid(column = 0 ,row=5)
#      54
# ---> 55 root.mainloop()
#
# ~\anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:

# %%
from selenium import webdriver

nav = webdriver.Chrome()
